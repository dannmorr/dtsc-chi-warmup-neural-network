# %% [markdown]
# # Deep Learnin' in the Mornin'

# %% [markdown]
# This morning we will build a basic Deep Learning Model, often referred to as a "Multi Layer Perceptron".
#
# Once we've create this model, we will use an Sklearn wrapper to run cross validation on our deep learning model!

# %% [markdown]
# **Import libraries**

# %%
# Dataset
from sklearn.datasets import load_breast_cancer

# Data Manipulation
import pandas as pd

# Turn of TensorFlow deprecation warnings
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning)
warnings.filterwarnings('ignore', category=FutureWarning)

# Modeling
import keras
from keras.models import Sequential 
from keras.layers import Dense 

# Model Validation
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
# Out:
# Using TensorFlow backend.

# %% [markdown]
# In the cell below we import the Sklearn breast cancer dataset.

# %%
data = load_breast_cancer()
X = data['data']
y = data['target']
df = pd.DataFrame(X)
df.columns = data['feature_names']
df['target'] = y
df.head(3)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38           122.8     1001.0          0.11840
# 1        20.57         17.77           132.9     1326.0          0.08474
# 2        19.69         21.25           130.0     1203.0          0.10960
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33            184.6      2019.0
# 1                 0.05667  ...          23.41            158.8      1956.0
# 2                 0.05999  ...          25.53            152.5      1709.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
#
#    worst symmetry  worst fractal dimension  target
# 0          0.4601                  0.11890       0
# 1          0.2750                  0.08902       0
# 2          0.3613                  0.08758       0
#
# [3 rows x 31 columns]

# %% [markdown]
# Okok.
#
# <u><b>In the cell below</b></u>
# - Create a train test split of the breast cancer dataset
#     - Set the random state to `2020`.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 2020)

# %% [markdown]
# Ok, now that our data is split, let's define a function that will compile a multi layer perceptron.

# %%
def compile_model():
    model = Sequential() 
    # The first parameter in a Keras Dense layer is the output shape after
    # the data has moved through that layer of the neural network. 
    # This parameter is required for every layer.
    # The input_dim parameter is only required for the first layer of a perceptron
    # and is the shape our of the training data. 
    model.add(Dense(14, input_dim=30, activation='relu')) 
    model.add(Dense(7, activation='relu')) 
    model.add(Dense(1, activation='sigmoid')) 
    # compile the keras model 
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy']) 
    return model

# %% [markdown]
# Now that we've done this, we can compile the model by calling the `compile_model` function, and then fit the model as we normally would when using deep learning models.

# %%
model = compile_model()
model.fit(X_train, y_train, epochs=150, batch_size=23)
# Out:
# Epoch 1/150
# 426/426 [==============================] - 0s 977us/step - loss: 1.8733 - acc: 0.3498
# Epoch 2/150
# 426/426 [==============================] - 0s 279us/step - loss: 0.8190 - acc: 0.4225
# Epoch 3/150
# 426/426 [==============================] - 0s 231us/step - loss: 0.7366 - acc: 0.6526
# Epoch 4/150
# 426/426 [==============================] - 0s 178us/step - loss: 0.6977 - acc: 0.3850
# Epoch 5/150
# 426/426 [==============================] - 0s 197us/step - loss: 0.4228 - acc: 0.8404
# Epoch 6/150
# 426/426 [==============================] - 0s 167us/step - loss: 0.3634 - acc: 0.8756
# Epoch 7/150
# 426/426 [==============================] - 0s 158us/step - loss: 0.3056 - acc: 0.8897
# Epoch 8/150
# 426/426 [==============================] - 0s 191us/step - loss: 0.3125 - acc: 0.9061
# Epoch 9/150
# 426/426 [==============================] - 0s 153us/step - loss: 0.3087 - acc: 0.9108
# Epoch 10/150
# 426/426 [==============================] - 0s 148us/step - loss: 0.2725 - acc: 0.9249
# Epoch 11/150
# 426/426 [==============================] - 0s 198us/step - loss: 0.3172 - acc: 0.8920
# 426/426 [==============================] - 0s 252us/step - loss: 0.1248 - acc: 0.9484
# Epoch 133/150
# 426/426 [==============================] - 0s 266us/step - loss: 0.1254 - acc: 0.9437
# Epoch 134/150
# 426/426 [==============================] - 0s 294us/step - loss: 0.1361 - acc: 0.9460
# Epoch 135/150
# 426/426 [==============================] - 0s 198us/step - loss: 0.1230 - acc: 0.9507
# Epoch 136/150
# 426/426 [==============================] - 0s 199us/step - loss: 0.1365 - acc: 0.9437
# Epoch 137/150
# 426/426 [==============================] - 0s 185us/step - loss: 0.1233 - acc: 0.9507
# Epoch 138/150
# 426/426 [==============================] - 0s 223us/step - loss: 0.1664 - acc: 0.9319
# Epoch 139/150
# 426/426 [==============================] - 0s 211us/step - loss: 0.1480 - acc: 0.9437
# Epoch 140/150
# 426/426 [==============================] - 0s 256us/step - loss: 0.1532 - acc: 0.9390
# Epoch 141/150
# 426/426 [==============================] - 0s 174us/step - loss: 0.1386 - acc: 0.9484
# Epoch 142/150
# 426/426 [==============================] - 0s 197us/step - loss: 0.1201 - acc: 0.9554
# Epoch 143/150
# 426/426 [==============================] - 0s 195us/step - loss: 0.1273 - acc: 0.9507
# Epoch 144/150
# 426/426 [==============================] - 0s 199us/step - loss: 0.1254 - acc: 0.9484
# Epoch 145/150
# 426/426 [==============================] - 0s 223us/step - loss: 0.1300 - acc: 0.9507
# Epoch 146/150
# 426/426 [==============================] - 0s 293us/step - loss: 0.1521 - acc: 0.9437
# Epoch 147/150
# 426/426 [==============================] - 0s 212us/step - loss: 0.1181 - acc: 0.9554
# Epoch 148/150
# 426/426 [==============================] - 0s 178us/step - loss: 0.1291 - acc: 0.9531
# Epoch 149/150
# 426/426 [==============================] - 0s 214us/step - loss: 0.1215 - acc: 0.9554
# Epoch 150/150
# 426/426 [==============================] - 0s 182us/step - loss: 0.2007 - acc: 0.9202

# %% [markdown]
# # Cross Validation

# %% [markdown]
# **With deep learning** it may not always be logistically possible to use cross validation. Depending on the size of the dataset, it can sometimes take multiple hours or even multiple days for a neural network to be fit on all of the training data.
#
#
# That being said, if it is feasible to use cross validation, you should! It will allow you to have higher confidence in your model's ability to generalize to new data.
#
# Keras provides a wrapper that allows us to easily use Sklearn's cross validation tools.
#
# <u><b>In the cell below, we import the Keras-Sklearn wrapper.</b></u>

# %%
from keras.wrappers.scikit_learn import KerasClassifier

# %% [markdown]
# **You may have noticed** that the ``compile_model`` function above does not ``fit`` the model to data.
#
# *The key to using ``KerasClassifier`` is defining a function that returns an unfit, but compiled model.*

# %%
model = KerasClassifier(build_fn=compile_model, epochs=150, batch_size=23, verbose=0)

# %% [markdown]
# **Now** we can use the Keras model exactly how we would use a normal sklearn classifier.

# %%
results = cross_val_score(model, X, y, cv=10)

# %%
results
# Out:
# array([0.80701754, 0.9122807 , 0.63157895, 0.50877193, 0.50877194,
#        0.78947368, 0.71929823, 0.22807018, 0.89473682, 0.96428571])

# %%
print('Average Accuracy: %.2f' % (results.mean()*100))
# Out:
# Average Accuracy: 69.64
